# %%
import pandas as pd
import numpy as np

# %%
from_npi = pd.read_csv('data/from_npi_clean.csv')
from_npi.head(3)
# Out:
#   prov_lastname prov_firstname prov_credential   prov_address1  \
# 0      NYLANDER        BARBARA            M.D.  345 23RD AVE N
# 1      NYLANDER        BARBARA            M.D.  345 23RD AVE N
# 2      PERRIGIN          JULIE              MD   219 CHURCH ST
#
#                               grouping           classification  \
# 0  Allopathic & Osteopathic Physicians  Obstetrics & Gynecology
# 1  Allopathic & Osteopathic Physicians  Obstetrics & Gynecology
# 2  Allopathic & Osteopathic Physicians          Family Medicine
#
#   specialization    from_npi      to_npi  patient_count  transaction_count
# 0     Gynecology  1003819046  1023055126             11                 11
# 1     Gynecology  1003819046  1093741464             12                 12
# 2            NaN  1750384780  1003863580            256                480

# %%
to_npi = pd.read_csv('data/to_npi_clean.csv')
to_npi.head()
# Out:
#           npi                       org_name prov_address1  \
# 0  1245233220  NORTHRIDGE SURGERY CENTER, LP  647 MYATT DR
# 1  1245233220  NORTHRIDGE SURGERY CENTER, LP  647 MYATT DR
# 2  1245233220  NORTHRIDGE SURGERY CENTER, LP  647 MYATT DR
# 3  1245233220  NORTHRIDGE SURGERY CENTER, LP  647 MYATT DR
# 4  1245233220  NORTHRIDGE SURGERY CENTER, LP  647 MYATT DR
#
#                             grouping classification       specialization  \
# 0  Ambulatory Health Care Facilities  Clinic/Center  Ambulatory Surgical
# 1  Ambulatory Health Care Facilities  Clinic/Center  Ambulatory Surgical
# 2  Ambulatory Health Care Facilities  Clinic/Center  Ambulatory Surgical
# 3  Ambulatory Health Care Facilities  Clinic/Center  Ambulatory Surgical
# 4  Ambulatory Health Care Facilities  Clinic/Center  Ambulatory Surgical
#
#      from_npi      to_npi  patient_count  transaction_count  average_day_wait
# 0  1023055126  1245233220             28                 30            96.967
# 1  1003910688  1245233220             24                 24           122.125
# 2  1003863580  1245233220             79                 82            82.159
# 3  1043297542  1245233220             45                 46            65.696
# 4  1083608459  1245233220             24                 37            23.622

# %%
from_npi.dtypes
# Out:
# prov_lastname        object
# prov_firstname       object
# prov_credential      object
# prov_address1        object
# grouping             object
# classification       object
# specialization       object
# from_npi              int64
# to_npi                int64
# patient_count         int64
# transaction_count     int64
# dtype: object

# %%
#from_npi = from_npi['from_npi', 'to_npi', 'patient_count', 'transaction_count'].astype(np.int32)

# %%
merge = from_npi.merge(to_npi, on = ['from_npi', 'to_npi', 'patient_count', 'transaction_count'], suffixes = ['_from', '_to'])

# %%
merge.head()
# Out:
#   prov_lastname prov_firstname prov_credential prov_address1_from  \
# 0      NYLANDER        BARBARA            M.D.     345 23RD AVE N
# 1      NYLANDER        BARBARA            M.D.     345 23RD AVE N
# 2      PERRIGIN          JULIE              MD      219 CHURCH ST
# 3      PERRIGIN          JULIE              MD      219 CHURCH ST
# 4      PERRIGIN          JULIE              MD      219 CHURCH ST
#
#                          grouping_from      classification_from  \
# 0  Allopathic & Osteopathic Physicians  Obstetrics & Gynecology
# 1  Allopathic & Osteopathic Physicians  Obstetrics & Gynecology
# 2  Allopathic & Osteopathic Physicians          Family Medicine
# 3  Allopathic & Osteopathic Physicians          Family Medicine
# 4  Allopathic & Osteopathic Physicians          Family Medicine
#
#   specialization_from    from_npi      to_npi  patient_count  \
# 0          Gynecology  1003819046  1023055126             11
# 1          Gynecology  1003819046  1093741464             12
# 2                 NaN  1750384780  1003863580            256
# 3                 NaN  1750384780  1013175215             29
# 4                 NaN  1750384780  1023055126             48
#
#    transaction_count         npi                                org_name  \
# 0                 11  1023055126  HCA HEALTH SERVICES OF TENNESSEE, INC.
# 1                 12  1093741464         ADVANCED DIAGNOSTIC IMAGING, PC
# 2                480  1003863580            ASSOCIATED PATHOLOGISTS, LLC
# 3                 77  1013175215          LHC HOMECARE OF TENNESSEE, LLC
# 4                 63  1023055126  HCA HEALTH SERVICES OF TENNESSEE, INC.
#
#             prov_address1_to                          grouping_to  \
# 0          2300 PATTERSON ST                            Hospitals
# 1     3024 BUSINESS PARK CIR                                  NaN
# 2  5301 VIRGINIA WAY STE 300  Allopathic & Osteopathic Physicians
# 3       2525 PERIMETER PLACE                             Agencies
# 4          2300 PATTERSON ST                            Hospitals
#
#              classification_to                        specialization_to  \
# 0  General Acute Care Hospital                                      NaN
# 1                          NaN                                      NaN
# 2                    Pathology  Anatomic Pathology & Clinical Pathology
# 3                  Home Health                                      NaN
# 4  General Acute Care Hospital                                      NaN
#
#    average_day_wait
# 0            13.182
# 1            34.083
# 2            55.685
# 3             0.026
# 4            36.921

# %%
merge.shape
# Out:
# (232215, 18)

# %%
merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 232215 entries, 0 to 232214
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   prov_lastname        232181 non-null  object
#  1   prov_firstname       232215 non-null  object
#  2   prov_credential      227087 non-null  object
#  3   prov_address1_from   232215 non-null  object
#  4   grouping_from        231863 non-null  object
#  5   classification_from  231863 non-null  object
#  6   specialization_from  123861 non-null  object
#  7   from_npi             232215 non-null  int64
#  8   to_npi               232215 non-null  int64
#  9   patient_count        232215 non-null  int64
#  10  transaction_count    232215 non-null  int64
#  11  npi                  232215 non-null  int64
#  12  org_name             232215 non-null  object
#  13  prov_address1_to     232215 non-null  object
#  14  grouping_to          215766 non-null  object
#  15  classification_to    215766 non-null  object
#  16  specialization_to    78341 non-null   object
#  17  average_day_wait     232215 non-null  float64
# dtypes: float64(1), int64(5), object(12)
# memory usage: 33.7+ MB

# %%
merge.average_day_wait = pd.to_numeric(merge.average_day_wait)

# %%
merge2 = merge[merge['transaction_count'] >= 50]

# %%
merge_final = merge2[merge2['average_day_wait'] < 50]

# %%
merge_final.head()
# Out:
#    prov_lastname prov_firstname prov_credential     prov_address1_from  \
# 3       PERRIGIN          JULIE              MD          219 CHURCH ST
# 4       PERRIGIN          JULIE              MD          219 CHURCH ST
# 6       PERRIGIN          JULIE              MD          219 CHURCH ST
# 9       PERRIGIN          JULIE              MD          219 CHURCH ST
# 11      PERRIGIN          JULIE              MD          219 CHURCH ST
# 18      PERRIGIN          JULIE              MD          219 CHURCH ST
# 19      PERRIGIN          JULIE              MD          219 CHURCH ST
# 20      PERRIGIN          JULIE              MD          219 CHURCH ST
# 21      PERRIGIN          JULIE              MD          219 CHURCH ST
# 24      PERRIGIN          JULIE              MD          219 CHURCH ST
# 25      PERRIGIN          JULIE              MD          219 CHURCH ST
# 26      PERRIGIN          JULIE              MD          219 CHURCH ST
# 34      PERRIGIN          JULIE              MD          219 CHURCH ST
# 35      PERRIGIN          JULIE              MD          219 CHURCH ST
# 37      PERRIGIN          JULIE              MD          219 CHURCH ST
# 45      PERRIGIN          JULIE              MD          219 CHURCH ST
# 46      PERRIGIN          JULIE              MD          219 CHURCH ST
# 47      PERRIGIN          JULIE              MD          219 CHURCH ST
# 62       PRESLEY        RICHARD            M.D.        2011 MURPHY AVE
# 65          ROSS          DAVID              MD  127 CRESTVIEW PARK DR
# 67          ROSS          DAVID              MD  127 CRESTVIEW PARK DR
# 68          ROSS          DAVID              MD  127 CRESTVIEW PARK DR
# 70          ROSS          DAVID              MD  127 CRESTVIEW PARK DR
# 71          ROSS          DAVID              MD  127 CRESTVIEW PARK DR
# 72          ROSS          DAVID              MD  127 CRESTVIEW PARK DR
#
#                           grouping_from      classification_from  \
# 3   Allopathic & Osteopathic Physicians          Family Medicine
# 4   Allopathic & Osteopathic Physicians          Family Medicine
# 6   Allopathic & Osteopathic Physicians          Family Medicine
# 9   Allopathic & Osteopathic Physicians          Family Medicine
# 11  Allopathic & Osteopathic Physicians          Family Medicine
# 18  Allopathic & Osteopathic Physicians          Family Medicine
# 19  Allopathic & Osteopathic Physicians          Family Medicine
# 20  Allopathic & Osteopathic Physicians          Family Medicine
# 21  Allopathic & Osteopathic Physicians          Family Medicine
# 24  Allopathic & Osteopathic Physicians          Family Medicine
# 25  Allopathic & Osteopathic Physicians          Family Medicine
# 26  Allopathic & Osteopathic Physicians          Family Medicine
# 34  Allopathic & Osteopathic Physicians          Family Medicine
# 35  Allopathic & Osteopathic Physicians          Family Medicine
# 37  Allopathic & Osteopathic Physicians          Family Medicine
# 45  Allopathic & Osteopathic Physicians          Family Medicine
# 46  Allopathic & Osteopathic Physicians          Family Medicine
# 47  Allopathic & Osteopathic Physicians          Family Medicine
# 62  Allopathic & Osteopathic Physicians  Obstetrics & Gynecology
# 65  Allopathic & Osteopathic Physicians        Internal Medicine
# 67  Allopathic & Osteopathic Physicians        Internal Medicine
# 68  Allopathic & Osteopathic Physicians        Internal Medicine
# 70  Allopathic & Osteopathic Physicians        Internal Medicine
# 71  Allopathic & Osteopathic Physicians        Internal Medicine
# 72  Allopathic & Osteopathic Physicians        Internal Medicine
#
#    specialization_from    from_npi      to_npi  patient_count  \
# 3                  NaN  1750384780  1013175215             29
# 4                  NaN  1750384780  1023055126             48
# 6                  NaN  1750384780  1043297542             35
# 9                  NaN  1750384780  1093741464             98
# 11                 NaN  1750384780  1104202761             32
# 18                 NaN  1750384780  1215932413             84
# 19                 NaN  1750384780  1235186800            268
# 20                 NaN  1750384780  1245393057             34
# 21                 NaN  1750384780  1285951095            300
# 24                 NaN  1750384780  1366870032             84
# 25                 NaN  1750384780  1396882205             24
# 26                 NaN  1750384780  1417983099             44
# 34                 NaN  1750384780  1568464873            195
# 35                 NaN  1750384780  1578576740             48
# 37                 NaN  1750384780  1659709178             49
# 45                 NaN  1750384780  1811955917             39
# 46                 NaN  1750384780  1861478489            226
# 47                 NaN  1750384780  1871530832            239
# 62                 NaN  1922001957  1578584199             98
# 65                 NaN  1073516001  1003863580             52
# 67                 NaN  1073516001  1023055126             55
# 68                 NaN  1073516001  1043297542             72
# 70                 NaN  1073516001  1073966503             35
# 71                 NaN  1073516001  1093741464            121
# 72                 NaN  1073516001  1104202761             96
#
#     transaction_count         npi  \
# 3                  77  1013175215
# 4                  63  1023055126
# 6                  63  1043297542
# 9                 153  1093741464
# 11                 71  1104202761
# 18                107  1215932413
# 19                614  1235186800
# 20                 54  1245393057
# 21               1022  1285951095
# 24                125  1366870032
# 25                 58  1396882205
# 26                 63  1417983099
# 34                376  1568464873
# 35                 60  1578576740
# 37                 64  1659709178
# 45                 81  1811955917
# 46                390  1861478489
# 47                445  1871530832
# 62                118  1578584199
# 65                 69  1003863580
# 67                 73  1023055126
# 68                132  1043297542
# 70                 52  1073966503
# 71                195  1093741464
# 72                177  1104202761
#
#                                         org_name           prov_address1_to  \
# 3                 LHC HOMECARE OF TENNESSEE, LLC       2525 PERIMETER PLACE
# 4         HCA HEALTH SERVICES OF TENNESSEE, INC.          2300 PATTERSON ST
# 6                          UROLOGY ASSOCIATES PC         2801 CHARLOTTE AVE
# 9                ADVANCED DIAGNOSTIC IMAGING, PC     3024 BUSINESS PARK CIR
# 11          VANDERBILT UNIVERSITY MEDICAL CENTER            1301 22ND AVE S
# 18                  ANESTHESIA MEDICAL GROUP, PC             110 29TH AVE N
# 19                           PATHGROUP LABS, LLC     1010 AIRPARK CENTER DR
# 20                          CENTENNIAL HEART LLC          2400 PATTERSON ST
# 21                         PERRIGIN MEDICAL PLLC              219 CHURCH ST
# 24        LUTHER LAKE EMERGENCY PHYSICIANS, PLLC           111 HIGHWAY 70 E
# 25          VANDERBILT UNIVERSITY MEDICAL CENTER  1211 MEDICAL CENTER DRIVE
# 26                      THE SURGICAL CLINIC PLLC            53 CENTURY BLVD
# 34                 DICKSON MEDICAL ASSOCIATES PC           113 HIGHWAY 70 E
# 35         DICKSON COUNTY OFFICE OF COUNTY MAYOR               284 COWAN RD
# 37          MATHIS DRIVE INPATIENT SERVICES PLLC           111 HIGHWAY 70 E
# 45                       TENNESSEE ONCOLOGY PLLC      2004 HAYES ST STE 800
# 46                         RADIOLOGY ALLIANCE PC      210 25TH AVENUE NORTH
# 47        CENTRAL TENNESSEE HOSPITAL CORPORATION           111 HIGHWAY 70 E
# 62                    TENNESSEE WOMEN'S CARE, PC             1900 CHURCH ST
# 65                  ASSOCIATED PATHOLOGISTS, LLC  5301 VIRGINIA WAY STE 300
# 67        HCA HEALTH SERVICES OF TENNESSEE, INC.          2300 PATTERSON ST
# 68                         UROLOGY ASSOCIATES PC         2801 CHARLOTTE AVE
# 70  CATARACT AND EYECARE CENTER,PROFESSIONAL LLC           10100 RAMSEY WAY
# 71               ADVANCED DIAGNOSTIC IMAGING, PC     3024 BUSINESS PARK CIR
# 72          VANDERBILT UNIVERSITY MEDICAL CENTER            1301 22ND AVE S
#
#                             grouping_to            classification_to  \
# 3                              Agencies                  Home Health
# 4                             Hospitals  General Acute Care Hospital
# 6   Allopathic & Osteopathic Physicians                      Urology
# 9                                   NaN                          NaN
# 11                                  NaN                          NaN
# 18  Allopathic & Osteopathic Physicians               Anesthesiology
# 19                         Laboratories  Clinical Medical Laboratory
# 20              Other Service Providers                   Specialist
# 21    Ambulatory Health Care Facilities                Clinic/Center
# 24  Allopathic & Osteopathic Physicians           Emergency Medicine
# 25                            Hospitals  General Acute Care Hospital
# 26  Allopathic & Osteopathic Physicians                      Surgery
# 34  Allopathic & Osteopathic Physicians              Family Medicine
# 35              Transportation Services                    Ambulance
# 37  Allopathic & Osteopathic Physicians            Internal Medicine
# 45  Allopathic & Osteopathic Physicians            Internal Medicine
# 46  Allopathic & Osteopathic Physicians                    Radiology
# 47                            Hospitals  General Acute Care Hospital
# 62  Allopathic & Osteopathic Physicians      Obstetrics & Gynecology
# 65  Allopathic & Osteopathic Physicians                    Pathology
# 67                            Hospitals  General Acute Care Hospital
# 68  Allopathic & Osteopathic Physicians                      Urology
# 70  Allopathic & Osteopathic Physicians                Ophthalmology
# 71                                  NaN                          NaN
# 72                                  NaN                          NaN
#
#                           specialization_to  average_day_wait
# 3                                       NaN             0.026
# 4                                       NaN            36.921
# 6                                       NaN            26.841
# 9                                       NaN            34.556
# 11                                      NaN            41.535
# 18                                      NaN            35.841
# 19                                      NaN            41.919
# 20                                      NaN            27.537
# 21                             Primary Care             0.000
# 24                                      NaN            31.448
# 25                                      NaN            32.759
# 26                                      NaN            26.730
# 34                                      NaN            28.761
# 35                           Land Transport            34.733
# 37                                      NaN            36.734
# 45                    Hematology & Oncology            24.728
# 46                     Diagnostic Radiology            14.136
# 47                                      NaN            16.344
# 62                                      NaN             0.000
# 65  Anatomic Pathology & Clinical Pathology            36.391
# 67                                      NaN            43.082
# 68                                      NaN            25.182
# 70                                      NaN            45.615
# 71                                      NaN            28.908
# 72                                      NaN            31.983

# %%
merge_final.shape
# Out:
# (44076, 18)

# %%
merge_final.describe()
# Out:
#            from_npi        to_npi  patient_count  transaction_count  \
# count  4.407600e+04  4.407600e+04   44076.000000       44076.000000
# mean   1.497884e+09  1.443334e+09     179.170025         271.862692
# std    2.881170e+08  2.870071e+08     717.397569        1262.604712
# min    1.003013e+09  1.003029e+09      11.000000          50.000000
# 25%    1.245369e+09  1.194945e+09      56.000000          74.000000
# 50%    1.487779e+09  1.437107e+09      92.000000         122.000000
# 75%    1.750321e+09  1.689745e+09     182.000000         258.000000
# max    1.992987e+09  1.992985e+09  102736.000000      185910.000000
#
#                 npi  average_day_wait
# count  4.407600e+04      44076.000000
# mean   1.443334e+09         23.832066
# std    2.870071e+08         16.130451
# min    1.003029e+09          0.000000
# 25%    1.194945e+09          8.000000
# 50%    1.437107e+09         25.762000
# 75%    1.689745e+09         37.884250
# max    1.992985e+09         49.996000

# %%
merge_final.transaction_count.sort_values(ascending = False)
# Out:
# 75557     185910
# 75827     156325
# 13204      42592
# 50561      30514
# 75575      15557
#            ...
# 19132         50
# 63104         50
# 62967         50
# 106592        50
# 79233         50
# Name: transaction_count, Length: 44076, dtype: int64

# %%
merge_final.sort_values(by=['transaction_count'], ascending = False)
# Out:
#        prov_lastname prov_firstname prov_credential  \
# 75557          WELCH          DEREK            M.D.
# 75827          WELCH          DEREK            M.D.
# 13204          KROLL          PETER            M.D.
# 50561         KNIGHT        KATHRYN            M.D.
# 75575          WELCH          DEREK            M.D.
# ...              ...            ...             ...
# 204836        LARSEN           HOPE            CRNA
# 22503         SACHAN          VIPIN            CRNA
# 119523       WORSHAM          RONDA     RNMSNCS FNP
# 204685       FRIESEN        BRITNEY            M.D.
# 189557         PATEL         MANISH            M.D.
#
#                prov_address1_from  \
# 75557           5301 VIRGINIA WAY
# 75827           5301 VIRGINIA WAY
# 13204   353 NEW SHACKLE ISLAND RD
# 50561           5301 VIRGINIA WAY
# 75575           5301 VIRGINIA WAY
# ...                           ...
# 204836             110 29TH AVE N
# 22503              110 29TH AVE N
# 119523        103 REDBUD DR STE E
# 204685          2300 PATTERSON ST
# 189557     3024 BUSINESS PARK CIR
#
#                                             grouping_from  \
# 75557                 Allopathic & Osteopathic Physicians
# 75827                 Allopathic & Osteopathic Physicians
# 13204                 Allopathic & Osteopathic Physicians
# 50561                 Allopathic & Osteopathic Physicians
# 75575                 Allopathic & Osteopathic Physicians
# ...                                                   ...
# 204836  Physician Assistants & Advanced Practice Nursi...
# 22503   Physician Assistants & Advanced Practice Nursi...
# 119523  Physician Assistants & Advanced Practice Nursi...
# 204685                Allopathic & Osteopathic Physicians
# 189557                Allopathic & Osteopathic Physicians
#
#                             classification_from  \
# 75557                                 Pathology
# 75827                                 Pathology
# 13204                            Anesthesiology
# 50561                                 Pathology
# 75575                                 Pathology
# ...                                         ...
# 204836  Nurse Anesthetist, Certified Registered
# 22503   Nurse Anesthetist, Certified Registered
# 119523                       Nurse Practitioner
# 204685                        Internal Medicine
# 189557                                Radiology
#
#                             specialization_from    from_npi      to_npi  \
# 75557   Anatomic Pathology & Clinical Pathology  1093753303  1003863580
# 75827   Anatomic Pathology & Clinical Pathology  1093753303  1235186800
# 13204                             Pain Medicine  1124020011  1104854124
# 50561   Anatomic Pathology & Clinical Pathology  1609848563  1003863580
# 75575   Anatomic Pathology & Clinical Pathology  1093753303  1023055126
# ...                                         ...         ...         ...
# 204836                                      NaN  1922390426  1891995163
# 22503                                       NaN  1972599090  1548239437
# 119523                                      NaN  1396840476  1104854124
# 204685                                      NaN  1083905822  1639588015
# 189557                     Diagnostic Radiology  1205070851  1902294549
#
#         patient_count  transaction_count         npi  \
# 75557          102736             185910  1003863580
# 75827           87351             156325  1235186800
# 13204           13319              42592  1104854124
# 50561           29299              30514  1003863580
# 75575            8351              15557  1023055126
# ...               ...                ...         ...
# 204836             50                 50  1891995163
# 22503              46                 50  1548239437
# 119523             17                 50  1104854124
# 204685             49                 50  1639588015
# 189557             45                 50  1902294549
#
#                                                  org_name  \
# 75557                        ASSOCIATED PATHOLOGISTS, LLC
# 75827                                 PATHGROUP LABS, LLC
# 13204                 ANESTHESIA SERVICES ASSOCIATES PLLC
# 50561                        ASSOCIATED PATHOLOGISTS, LLC
# 75575              HCA HEALTH SERVICES OF TENNESSEE, INC.
# ...                                                   ...
# 204836                                            ACLA PC
# 22503                    NASHVILLE VISION ASSOCIATES, PLC
# 119523                ANESTHESIA SERVICES ASSOCIATES PLLC
# 204685  HOSPITAL BASED MEDICAL SERVICES OF TENNESSEE-I PC
# 189557                      GENESIS PALLIATIVE CARE, PLLC
#
#                  prov_address1_to  \
# 75557   5301 VIRGINIA WAY STE 300
# 75827      1010 AIRPARK CENTER DR
# 13204      131 SAUNDERSVILLE ROAD
# 50561   5301 VIRGINIA WAY STE 300
# 75575           2300 PATTERSON ST
# ...                           ...
# 204836         2000 CHURCH STREET
# 22503             4306 HARDING RD
# 119523     131 SAUNDERSVILLE ROAD
# 204685          2300 PATTERSON ST
# 189557  1642 WESTGATE CIR STE 202
#
#                                               grouping_to  \
# 75557                 Allopathic & Osteopathic Physicians
# 75827                                        Laboratories
# 13204                 Allopathic & Osteopathic Physicians
# 50561                 Allopathic & Osteopathic Physicians
# 75575                                           Hospitals
# ...                                                   ...
# 204836                Allopathic & Osteopathic Physicians
# 22503                             Other Service Providers
# 119523                Allopathic & Osteopathic Physicians
# 204685                Allopathic & Osteopathic Physicians
# 189557  Physician Assistants & Advanced Practice Nursi...
#
#                   classification_to                        specialization_to  \
# 75557                     Pathology  Anatomic Pathology & Clinical Pathology
# 75827   Clinical Medical Laboratory                                      NaN
# 13204                Anesthesiology                            Pain Medicine
# 50561                     Pathology  Anatomic Pathology & Clinical Pathology
# 75575   General Acute Care Hospital                                      NaN
# ...                             ...                                      ...
# 204836                    Pathology  Anatomic Pathology & Clinical Pathology
# 22503                    Specialist                                      NaN
# 119523               Anesthesiology                            Pain Medicine
# 204685           Emergency Medicine                                      NaN
# 189557           Nurse Practitioner                                      NaN
#
#         average_day_wait
# 75557              0.000
# 75827              0.455
# 13204              0.013
# 50561              0.000
# 75575              7.874
# ...                  ...
# 204836            13.100
# 22503              2.020
# 119523            16.020
# 204685            41.680
# 189557            43.140
#
# [44076 rows x 18 columns]

# %%
address1 = merge_final.groupby('prov_address1_from')['transaction_count'].count().sort_values(ascending = False)

# %%
address1.head(50)
# Out:
# prov_address1_from
# 3601 THE VANDERBILT CLINIC     2200
# 210 25TH AVE N STE 602         1611
# 3601 TVC                       1514
# 110 29TH AVE N                 1294
# 3024 BUSINESS PARK CIR         1279
# 2400 PATTERSON ST              1182
# 210 25TH AVE N                 1073
# 4230 HARDING RD                 881
# 3443 DICKERSON PIKE             756
# 110 29TH AVE N STE 202          638
# 1224 TROTWOOD AVE               638
# 4230 HARDING PIKE               598
# 353 NEW SHACKLE ISLAND RD       553
# 4220 HARDING PIKE               516
# 300 20TH AVE N                  508
# 5301 VIRGINIA WAY               484
# 300 STEAM PLANT RD              446
# 5651 FRIST BLVD                 434
# 2300 PATTERSON ST               386
# 5653 FRIST BLVD                 378
# 1700 MEDICAL CENTER PKWY        357
# 1272 GARRISON DR                354
# 1800 MEDICAL CENTER PKWY        353
# 2000 CHURCH ST                  339
# 4220 HARDING RD                 338
# 222 22ND AVE N                  314
# 1840 MEDICAL CENTER PKWY        294
# 1222 TROTWOOD AVE               259
# 3441 DICKERSON PIKE             254
# 345 23RD AVE N                  239
# 28 WHITE BRIDGE RD              231
# 330 23RD AVE N                  227
# 397 WALLACE RD                  223
# 2010 CHURCH ST                  212
# 166 E MAIN ST                   203
# 854 W JAMES CAMPBELL BLVD       199
# 212 HERITAGE PARK DR            196
# 5655 FRIST BLVD                 191
# 2801 CHARLOTTE AVE              187
# 1161 21ST AVE S                 187
# 250 25TH AVE N                  186
# 4323 CAROTHERS PKWY             184
# 300 STONECREST BLVD             173
# 127 CRESTVIEW PARK DR           169
# 1407 W BADDOUR PKWY             161
# 111 HIGHWAY 70 E                153
# 391 WALLACE RD                  148
# 4323 CAROTHERS PKWY STE 201     145
# 2011 MURPHY AVE                 133
# 1050 N JAMES CAMPBELL BLVD      132
# Name: transaction_count, dtype: int64

# %%
address3 = merge_final.groupby('prov_address1_from')['transaction_count'].sum().sort_values(ascending = False)

# %%
address3.head(50)
# Out:
# prov_address1_from
# 5301 VIRGINIA WAY              654041
# 3601 THE VANDERBILT CLINIC     637489
# 3601 TVC                       580598
# 3024 BUSINESS PARK CIR         526244
# 210 25TH AVE N STE 602         451600
# 2400 PATTERSON ST              344949
# 210 25TH AVE N                 290453
# 4230 HARDING RD                275085
# 1224 TROTWOOD AVE              222834
# 353 NEW SHACKLE ISLAND RD      202945
# 3443 DICKERSON PIKE            202289
# 4230 HARDING PIKE              165434
# 110 29TH AVE N                 154108
# 4220 HARDING PIKE              129054
# 300 20TH AVE N                 117990
# 5651 FRIST BLVD                115877
# 300 STEAM PLANT RD             115750
# 1272 GARRISON DR                98718
# 1700 MEDICAL CENTER PKWY        98366
# 4220 HARDING RD                 95373
# 1840 MEDICAL CENTER PKWY        93667
# 222 22ND AVE N                  87509
# 2300 PATTERSON ST               82241
# 2000 CHURCH ST                  81402
# 5653 FRIST BLVD                 80835
# 110 29TH AVE N STE 202          78715
# 1222 TROTWOOD AVE               77688
# 212 HERITAGE PARK DR            73567
# 345 23RD AVE N                  72640
# 28 WHITE BRIDGE RD              65229
# 330 23RD AVE N                  63866
# 854 W JAMES CAMPBELL BLVD       61934
# 1800 MEDICAL CENTER PKWY        61726
# 4323 CAROTHERS PKWY             58919
# 1161 21ST AVE S                 58822
# 3441 DICKERSON PIKE             54811
# 127 CRESTVIEW PARK DR           53915
# 2801 CHARLOTTE AVE              52684
# 166 E MAIN ST                   50855
# 2010 CHURCH ST                  50352
# 397 WALLACE RD                  48106
# 1050 N JAMES CAMPBELL BLVD      47832
# 170 OMNI DR                     45441
# 250 25TH AVE N                  45149
# 5655 FRIST BLVD                 43311
# 620 HARTSVILLE PIKE             42980
# 4323 CAROTHERS PKWY STE 201     41709
# 300 STONECREST BLVD             41685
# 1215 21ST AVE S                 41462
# 5801 CROSSINGS BLVD             37888
# Name: transaction_count, dtype: int64

# %%
# Group by specialization, and group by names to identify relationships. Filter out Vanderbilt as the "to" recipient. 
#Also, follow ReadMe instrux on filtering for specific specialties

# %%
#the following code to filter out Vanderbilt recipient sites produced 0 rows
vandy_lookup = merge_final['org_name'].str.findall(r'\bVANDERBILT\b')

# %%
vandy_lookup
# Out:
# 3                   []
# 4                   []
# 6                   []
# 9                   []
# 11        [VANDERBILT]
#               ...
# 232183              []
# 232184              []
# 232193              []
# 232204              []
# 232213              []
# Name: org_name, Length: 44076, dtype: object

# %% [raw]
# vandy_lookup.describe()

# %%
merge_final['to_is_vandy'] = merge_final['org_name'].str.contains('VAND', case = False, na = False).astype(int)
# Out:
# <ipython-input-61-27c2d1f76649>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge_final['to_is_vandy'] = merge_final['org_name'].str.contains('VAND', case = False, na = False).astype(int)

# %%
merge_final
# Out:
#        prov_lastname prov_firstname prov_credential  \
# 3           PERRIGIN          JULIE              MD
# 4           PERRIGIN          JULIE              MD
# 6           PERRIGIN          JULIE              MD
# 9           PERRIGIN          JULIE              MD
# 11          PERRIGIN          JULIE              MD
# ...              ...            ...             ...
# 232183        GILLEY          TYLER              PA
# 232184        STILES          LAURA        MS, PA-C
# 232193         BLATT      KATHERINE             DPT
# 232204      TRIVISON         NICOLE             DPT
# 232213          BASS       JONATHAN              PT
#
#                 prov_address1_from  \
# 3                    219 CHURCH ST
# 4                    219 CHURCH ST
# 6                    219 CHURCH ST
# 9                    219 CHURCH ST
# 11                   219 CHURCH ST
# ...                            ...
# 232183              3085 SPARTA ST
# 232184            2630 ELM HILL PK
# 232193          132 N BELVEDERE DR
# 232204        5073 MAIN ST STE 120
# 232213  1050 N JAMES CAMPBELL BLVD
#
#                                             grouping_from  \
# 3                     Allopathic & Osteopathic Physicians
# 4                     Allopathic & Osteopathic Physicians
# 6                     Allopathic & Osteopathic Physicians
# 9                     Allopathic & Osteopathic Physicians
# 11                    Allopathic & Osteopathic Physicians
# ...                                                   ...
# 232183  Physician Assistants & Advanced Practice Nursi...
# 232184  Physician Assistants & Advanced Practice Nursi...
# 232193  Respiratory, Developmental, Rehabilitative and...
# 232204  Respiratory, Developmental, Rehabilitative and...
# 232213  Respiratory, Developmental, Rehabilitative and...
#
#         classification_from specialization_from    from_npi      to_npi  \
# 3           Family Medicine                 NaN  1750384780  1013175215
# 4           Family Medicine                 NaN  1750384780  1023055126
# 6           Family Medicine                 NaN  1750384780  1043297542
# 9           Family Medicine                 NaN  1750384780  1093741464
# 11          Family Medicine                 NaN  1750384780  1104202761
# ...                     ...                 ...         ...         ...
# 232183  Physician Assistant                 NaN  1598281388  1093741464
# 232184  Physician Assistant                 NaN  1811412612  1487848800
# 232193   Physical Therapist                 NaN  1760908362  1962417444
# 232204   Physical Therapist                 NaN  1134647613  1962417444
# 232213   Physical Therapist                 NaN  1265943328  1922057181
#
#         patient_count  transaction_count         npi  \
# 3                  29                 77  1013175215
# 4                  48                 63  1023055126
# 6                  35                 63  1043297542
# 9                  98                153  1093741464
# 11                 32                 71  1104202761
# ...               ...                ...         ...
# 232183             55                 73  1093741464
# 232184             55                 57  1487848800
# 232193             40                256  1962417444
# 232204             30                197  1962417444
# 232213             19                 65  1922057181
#
#                                       org_name            prov_address1_to  \
# 3               LHC HOMECARE OF TENNESSEE, LLC        2525 PERIMETER PLACE
# 4       HCA HEALTH SERVICES OF TENNESSEE, INC.           2300 PATTERSON ST
# 6                        UROLOGY ASSOCIATES PC          2801 CHARLOTTE AVE
# 9              ADVANCED DIAGNOSTIC IMAGING, PC      3024 BUSINESS PARK CIR
# 11        VANDERBILT UNIVERSITY MEDICAL CENTER             1301 22ND AVE S
# ...                                        ...                         ...
# 232183         ADVANCED DIAGNOSTIC IMAGING, PC      3024 BUSINESS PARK CIR
# 232184      THE LITTLE CLINIC OF TENNESSEE LLC         5713 EDMONDSON PIKE
# 232193                        AGILITAS USA INC             131B HATCHER LN
# 232204                        AGILITAS USA INC             131B HATCHER LN
# 232213              MID-TENNESSEE BONE & JOINT  1050 N JAMES CAMPBELL BLVD
#
#                                               grouping_to  \
# 3                                                Agencies
# 4                                               Hospitals
# 6                     Allopathic & Osteopathic Physicians
# 9                                                     NaN
# 11                                                    NaN
# ...                                                   ...
# 232183                                                NaN
# 232184  Physician Assistants & Advanced Practice Nursi...
# 232193                  Ambulatory Health Care Facilities
# 232204                  Ambulatory Health Care Facilities
# 232213                Allopathic & Osteopathic Physicians
#
#                   classification_to specialization_to  average_day_wait  \
# 3                       Home Health               NaN             0.026
# 4       General Acute Care Hospital               NaN            36.921
# 6                           Urology               NaN            26.841
# 9                               NaN               NaN            34.556
# 11                              NaN               NaN            41.535
# ...                             ...               ...               ...
# 232183                          NaN               NaN             0.000
# 232184           Nurse Practitioner            Family             0.000
# 232193                Clinic/Center  Physical Therapy             0.000
# 232204                Clinic/Center  Physical Therapy             0.000
# 232213          Orthopaedic Surgery               NaN             0.000
#
#         to_is_vandy
# 3                 0
# 4                 0
# 6                 0
# 9                 0
# 11                1
# ...             ...
# 232183            0
# 232184            0
# 232193            0
# 232204            0
# 232213            0
#
# [44076 rows x 19 columns]

# %%
merge_final.to_is_vandy.count()
# Out:
# 44076

# %%
#create new db that removes any rows where the "org_name", represented by the 'to_is_vandy' includes Vand is removed 
no_vandy = merge_final[merge_final['to_is_vandy'] == 0]

# %%
no_vandy.shape
# Out:
# (38867, 19)

# %%
no_vandy.groupby('prov_address1_from')['transaction_count'].sum().sort_values(ascending = False)
# Out:
# prov_address1_from
# 5301 VIRGINIA WAY            651771
# 3024 BUSINESS PARK CIR       500279
# 210 25TH AVE N STE 602       450609
# 2400 PATTERSON ST            336281
# 210 25TH AVE N               288920
#                               ...
# 122 HIGHWAY 76                   50
# 329 WARFIELD BOULEVARD           50
# 607 W DUE WEST AVE STE 97        50
# 259 DIXON SPRINGS HWY            50
# 1200 GALLATIN PIKE S             50
# Name: transaction_count, Length: 1704, dtype: int64

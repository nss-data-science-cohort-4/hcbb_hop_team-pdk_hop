# %% [markdown]
# Load in the 2 datasets:  the nppes & hop_team datasets merged on "to_npi", and the nppes & hop_team datasets merged on "from_npi"

# %%
import pandas as pd
import numpy as np

# %%
to_npi = pd.read_csv('data/team_nppes_to.csv', index_col = 0)
to_npi.head()
# Out:
# C:\Users\daily\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (19,20,21,23,24,26,27,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            npi  entity_type_code  replacement_npi  \
# 7   1003028770               2.0              NaN
# 8   1003028770               2.0              NaN
# 9   1003028770               2.0              NaN
# 10  1003028770               2.0              NaN
# 11  1003028770               2.0              NaN
#
#    employer_identification_number_ein  \
# 7                           <UNAVAIL>
# 8                           <UNAVAIL>
# 9                           <UNAVAIL>
# 10                          <UNAVAIL>
# 11                          <UNAVAIL>
#
#    provider_organization_name_legal_business_name  \
# 7                     SPRING HILL DERMATOLOGY PLC
# 8                     SPRING HILL DERMATOLOGY PLC
# ...

# %%
#drop unnecessary columns 
to_npi = to_npi.drop(columns = ['replacement_npi','employer_identification_number_ein',
                                       'provider_business_practice_location_address_city_name',
                                       'provider_business_practice_location_address_state_name',
                                       'provider_business_practice_location_address_postal_code',
                                       'provider_gender_code', 'effective_date', 'deactivation_date', 
                                       'last_modified_date','notes', 'display_name', 'postal_code', 'zip', 
                                       'cbsa', 'res_ratio', 'bus_ratio', 'oth_ratio'], axis = 1)

# %%
to_npi.shape
# Out:
# (650980, 25)

# %%
to_npi.head(3)
# Out:
#           npi  entity_type_code  \
# 7  1003028770               2.0
# 8  1003028770               2.0
# 9  1003028770               2.0
#
#   provider_organization_name_legal_business_name  \
# 7                    SPRING HILL DERMATOLOGY PLC
# 8                    SPRING HILL DERMATOLOGY PLC
# 9                    SPRING HILL DERMATOLOGY PLC
#
#    provider_last_name_legal_name  provider_first_name  provider_middle_name  \
# 7                            NaN                  NaN                   NaN
# 8                            NaN                  NaN                   NaN
# 9                            NaN                  NaN                   NaN
#
#    provider_name_prefix_text  provider_name_suffix_text  \
# 7                        NaN                        NaN
# 8                        NaN                        NaN
# 9                        NaN                        NaN
#
#    provider_credential_text  \
# 7                       NaN
# 8                       NaN
# ...

# %%
to_npi = to_npi.rename(columns = {'entity_type_code':'to_npi_entity_type', 'provider_organization_name_legal_business_name':'org_name', 
                                  'provider_last_name_legal_name':'prov_lastname', 'provider_first_name':'prov_firstname', 'provider_middle_name':'prov_middle',
                                  'provider_name_prefix_text':'prov_prefix', 'provider_name_suffix_text':'prov_suffix',
                                  'provider_credential_text':'prov_credential', 'provider_first_line_business_practice_location_address':'prov_address1',
                                  'provider_second_line_business_practice_location_address':'prov_address2'})

# %%
to_npi.set_index("npi", inplace = True)

# %%
to_npi.head(3)
# Out:
#             to_npi_entity_type                     org_name  prov_lastname  \
# npi
# 1003028770                 2.0  SPRING HILL DERMATOLOGY PLC            NaN
# 1003028770                 2.0  SPRING HILL DERMATOLOGY PLC            NaN
# 1003028770                 2.0  SPRING HILL DERMATOLOGY PLC            NaN
#
#             prov_firstname  prov_middle  prov_prefix  prov_suffix  \
# npi
# 1003028770             NaN          NaN          NaN          NaN
# 1003028770             NaN          NaN          NaN          NaN
# 1003028770             NaN          NaN          NaN          NaN
#
#             prov_credential      prov_address1 prov_address2  ...  \
# npi                                                           ...
# 1003028770              NaN  1229 RESERVE BLVD     SUITE 200  ...
# 1003028770              NaN  1229 RESERVE BLVD     SUITE 200  ...
# 1003028770              NaN  1229 RESERVE BLVD     SUITE 200  ...
#
# ...

# %%
from_npi = pd.read_csv('data/team_nppes_from.csv', index_col = 0)
from_npi.head()
# Out:
# C:\Users\daily\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (13,14,15,16,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            npi  entity_type_code  \
# 1   1023223898               1.0
# 7   1033109285               1.0
# 10  1033109285               1.0
# 17  1023343910               1.0
# 33  1043296890               1.0
#
#     provider_organization_name_legal_business_name  \
# 1                                              NaN
# 7                                              NaN
# 10                                             NaN
# 17                                             NaN
# 33                                             NaN
#
#    provider_last_name_legal_name provider_first_name provider_middle_name  \
# 1                       WOODFORD             RANDALL                    L
# ...

# %%
from_npi.set_index("npi", inplace = True)

# %%
from_npi.shape
# Out:
# (922957, 24)

# %%
from_npi = from_npi.rename(columns = {'entity_type_code':'from_npi_entity_type', 'provider_organization_name_legal_business_name':'org_name', 
                                  'provider_last_name_legal_name':'prov_lastname', 'provider_first_name':'prov_firstname', 'provider_middle_name':'prov_middle',
                                  'provider_name_prefix_text':'prov_prefix', 'provider_name_suffix_text':'prov_suffix',
                                  'provider_credential_text':'prov_credential', 'provider_first_line_business_practice_location_address':'prov_address1',
                                  'provider_second_line_business_practice_location_address':'prov_address2'})

# %%
from_npi.head(3)
# Out:
#             from_npi_entity_type  org_name prov_lastname prov_firstname  \
# npi
# 1023223898                   1.0       NaN      WOODFORD        RANDALL
# 1033109285                   1.0       NaN        NISBET           JOHN
# 1033109285                   1.0       NaN        NISBET           JOHN
#
#            prov_middle prov_prefix prov_suffix prov_credential  \
# npi
# 1023223898           L         NaN         NaN              MD
# 1033109285           J         DR.         NaN              MD
# 1033109285           J         DR.         NaN              MD
#
#                      prov_address1 prov_address2  ... specialization  \
# npi                                               ...
# 1023223898       5301 VIRGINIA WAY           300  ...            NaN
# 1033109285  3024 BUSINESS PARK CIR           NaN  ...            NaN
# 1033109285  3024 BUSINESS PARK CIR           NaN  ...            NaN
#
# ...

# %%
from_npi.specialization.nunique()
# Out:
# 1

# %%
to_npi.specialization.nunique()
# Out:
# 0

# %%
from_npi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 922957 entries, 1023223898 to 1245348580
# Data columns (total 24 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   from_npi_entity_type  922957 non-null  float64
#  1   org_name              0 non-null       float64
#  2   prov_lastname         922845 non-null  object
#  3   prov_firstname        922957 non-null  object
#  4   prov_middle           743381 non-null  object
#  5   prov_prefix           449342 non-null  object
#  6   prov_suffix           53932 non-null   object
#  7   prov_credential       905238 non-null  object
#  8   prov_address1         922957 non-null  object
#  9   prov_address2         387764 non-null  object
#  10  taxonomy              922957 non-null  object
#  11  code                  1168 non-null    object
#  12  grouping              1168 non-null    object
#  13  classification        1168 non-null    object
# ...

# %%
to_npi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 650980 entries, 1003028770 to 1255365987
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   to_npi_entity_type  650980 non-null  float64
#  1   org_name            650980 non-null  object
#  2   prov_lastname       0 non-null       float64
#  3   prov_firstname      0 non-null       float64
#  4   prov_middle         0 non-null       float64
#  5   prov_prefix         0 non-null       float64
#  6   prov_suffix         0 non-null       float64
#  7   prov_credential     0 non-null       float64
#  8   prov_address1       650980 non-null  object
#  9   prov_address2       216139 non-null  object
#  10  taxonomy            650980 non-null  object
#  11  code                179 non-null     object
#  12  grouping            179 non-null     object
#  13  classification      179 non-null     object
# ...

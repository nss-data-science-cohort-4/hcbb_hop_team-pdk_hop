# %%
import pandas as pd

# %%
#Review Hop Teaming Dataset
hop_review = pd.read_csv('data/DocGraph_Hop_Teaming_2017.csv', nrows = 100)

# %%
hop_review.head()
# Out:
#      from_npi      to_npi  patient_count  transaction_count  average_day_wait  \
# 0  1003863580  1000000004             19                 19           108.895
# 1  1043250400  1000000004             20                 20            87.000
# 2  1033239413  1000000004             20                 20            58.800
# 3  1033142146  1000000004            491                535            10.232
# 4  1013957562  1000000004             25                 26            78.692
#
#    std_day_wait
# 0        84.598
# 1        77.173
# 2        76.982
# 3        36.558
# 4        59.305

# %%
hop_review.shape
# Out:
# (100, 6)

# %%
#Review nppes Dataset 
nppes_review = pd.read_csv('data/npidata_pfile_20050523-20210207.csv', nrows = 100)
nppes_review
# Out:
#            NPI  Entity Type Code  Replacement NPI  \
# 0   1679576722               1.0              NaN
# 1   1588667638               1.0              NaN
# 2   1497758544               2.0              NaN
# 3   1306849450               1.0              NaN
# 4   1215930367               1.0              NaN
# ..         ...               ...              ...
# 95  1649273673               1.0              NaN
# 96  1083617013               2.0              NaN
# 97  1992708929               2.0              NaN
# 98  1801899836               1.0              NaN
# 99  1710980743               1.0              NaN
#
#    Employer Identification Number (EIN)  \
# 0                                   NaN
# 1                                   NaN
# 2                             <UNAVAIL>
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 95                                  NaN
# 96                            <UNAVAIL>
# 97                            <UNAVAIL>
# 98                                  NaN
# 99                                  NaN
#
#    Provider Organization Name (Legal Business Name)  \
# 0                                               NaN
# 1                                               NaN
# 2            CUMBERLAND COUNTY HOSPITAL SYSTEM, INC
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 95                                              NaN
# 96                                  AMOSKEAG HEALTH
# 97                  NOVAMED MANAGEMENT SERVICES LLC
# 98                                              NaN
# 99                                              NaN
#
#    Provider Last Name (Legal Name) Provider First Name Provider Middle Name  \
# 0                            WIEBE               DAVID                    A
# 1                          PILCHER             WILLIAM                    C
# 2                              NaN                 NaN                  NaN
# 3                          SMITSON              HAROLD                LEROY
# 4                          GRESSOT             LAURENT                  NaN
# ..                             ...                 ...                  ...
# 95                      KOPCZYNSKI                TODD                    M
# 96                             NaN                 NaN                  NaN
# 97                             NaN                 NaN                  NaN
# 98                        ZICHELLA               SARAH                    L
# 99                           ALLEN                EVAN                    C
#
#    Provider Name Prefix Text Provider Name Suffix Text  ...  \
# 0                        NaN                       NaN  ...
# 1                        DR.                       NaN  ...
# 2                        NaN                       NaN  ...
# 3                        DR.                        II  ...
# 4                        DR.                       NaN  ...
# ..                       ...                       ...  ...
# 95                       NaN                       NaN  ...
# 96                       NaN                       NaN  ...
# 97                       NaN                       NaN  ...
# 98                      MRS.                       NaN  ...
# 99                       NaN                       NaN  ...
#
#    Healthcare Provider Taxonomy Group_7 Healthcare Provider Taxonomy Group_8  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
# ..                                  ...                                  ...
# 95                                  NaN                                  NaN
# 96                                  NaN                                  NaN
# 97                                  NaN                                  NaN
# 98                                  NaN                                  NaN
# 99                                  NaN                                  NaN
#
#     Healthcare Provider Taxonomy Group_9  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 95                                   NaN
# 96                                   NaN
# 97                                   NaN
# 98                                   NaN
# 99                                   NaN
#
#    Healthcare Provider Taxonomy Group_10  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 95                                   NaN
# 96                                   NaN
# 97                                   NaN
# 98                                   NaN
# 99                                   NaN
#
#    Healthcare Provider Taxonomy Group_11  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 95                                   NaN
# 96                                   NaN
# 97                                   NaN
# 98                                   NaN
# 99                                   NaN
#
#    Healthcare Provider Taxonomy Group_12  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 95                                   NaN
# 96                                   NaN
# 97                                   NaN
# 98                                   NaN
# 99                                   NaN
#
#    Healthcare Provider Taxonomy Group_13  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 95                                   NaN
# 96                                   NaN
# 97                                   NaN
# 98                                   NaN
# 99                                   NaN
#
#     Healthcare Provider Taxonomy Group_14  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 95                                    NaN
# 96                                    NaN
# 97                                    NaN
# 98                                    NaN
# 99                                    NaN
#
#    Healthcare Provider Taxonomy Group_15  Certification Date
# 0                                    NaN                 NaN
# 1                                    NaN                 NaN
# 2                                    NaN                 NaN
# 3                                    NaN                 NaN
# 4                                    NaN                 NaN
# ..                                   ...                 ...
# 95                                   NaN          09/29/2020
# 96                                   NaN          01/31/2020
# 97                                   NaN                 NaN
# 98                                   NaN                 NaN
# 99                                   NaN                 NaN
#
# [100 rows x 330 columns]

# %%
#Determine which columns have Taxonomy Switch as "Y".  Answer:  1,2,3,4,7
nppes_review['Healthcare Provider Primary Taxonomy Switch_4'].unique()
# Out:
# array([nan, 'X', 'Y', 'N'], dtype=object)

# %% [markdown]
# Let's say that our goal is to find all incidents where the Tencode Description was 'SHOTS FIRED'.
#
# One thing we could try is to use the chunksize argument in our pd.read_csv call. What this does is to create an iterable which returns just the specified number of rows at a time.
#
# Iterating through a file using chunks can look like this, but can also be structured differently (for example, using a list comprehension).
#
# ```
# chunks = pd.read_csv('data/Metro_Nashville_Police_Department_Calls_for_Service.csv', chunksize = 10000)
#
# for chunk in chunks:
#     # Do something
# ```

# %% [markdown]
# Here is what we need to do:
#
# 1. Create an iterable by using the chunksize argument.
#
# 2. For each chunk, filter to just the rows where the 'Tencode Description' column is 'SHOTS FIRED'. Store these rows.
#
# 3. Concatenate all the results together into a single dataframe.

# %%
#example
# shots_fired = pd.concat([chunk[chunk['Tencode Description'] == 'SHOTS FIRED'] 
#                          for chunk in pd.read_csv('data/Metro_Nashville_Police_Department_Calls_for_Service.csv', 
#                                                   chunksize = 10000)])

# %% [markdown]
# The above solution would work for one-off tasks. However, if you are going to be working extensively with a dataset or merging two large datasets, it would be a bit cumbersome to have to chunk through one or both datasets multiple times.
#
# As an alternative to working in just Python, we can use a different tool which works better on large datasets - SQL.
#
# In this notebook, we will make use of SQLite, which is a file-based relational database management system. We can interact with SQLite databases through the sqlite3 library.

# %%
import sqlite3

# %% [markdown]
# First, we need to connect to our database. The connect function will either create a new database if one does not already exist or connect to an existing one.

# %%
#create an empty df
db = sqlite3.connect('data/hop_teaming.sqlite')

# %% [markdown]
# Now, we can chunk through the data and for each row, add the rows to a table in our sqlite database.
# To keep track of how much progress has been made, we can use the `tqdm` library.

# %%
from tqdm.notebook import tqdm  
#tqdm is a function that helps with chunking by providing time bar

# %%
for chunk in tqdm(pd.read_csv('data/DocGraph_Hop_Teaming_2017.csv', chunksize = 10000)):
    chunk.columns = [x.lower().replace(' ', '_') for x in chunk.columns]      # Clean up the column names
    chunk.to_sql('team', db, if_exists = 'append', index = False)            # Append the chunk to a calls table
    
    #Q: on 3rd line, 'team' is the new table name within large db called hop_teaming.sqlite
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %% [markdown]
# To speed up queries which use a specific column, we can create an **index** on that column. This causes the database to store that column in a way that helps it to retrieve rows quicker.

# %%
#ignore error code below if I run 2+ times 
db.execute('CREATE INDEX from_npi ON team(from_npi)')

# %% [markdown]
# Finally, we should close our database connection.

# %%
db.close()

# %% [markdown]
# Now, let's see how long it takes to find all rows corresponding to 'SHOTS FIRED'.

# %%
#shots_sqlite.head()
# Out:
#      event_number           call_received  complaint_number shift  tencode  \
# 0  PD202000845566  11/21/2020 09:24:37 AM               NaN  None       83
# 1  PD202000712516  09/23/2020 09:47:43 PM               NaN  None       83
# 2  PD202000711572  09/23/2020 01:42:22 PM               NaN  None       83
# 3  PD202000712380  09/23/2020 07:54:59 PM               NaN  None       83
# 4  PD202000712444  09/23/2020 08:38:40 PM               NaN  None       83
#
#   tencode_description tencode_suffix tencode_suffix_description  \
# 0         SHOTS FIRED              P                   PROGRESS
# 1         SHOTS FIRED              P                   PROGRESS
# 2         SHOTS FIRED              R                     REPORT
# 3         SHOTS FIRED              P                   PROGRESS
# 4         SHOTS FIRED              P                   PROGRESS
#
#   disposition_code disposition_description  block street_name unit_dispatched  \
# 0               10                    None    NaN        None            611A
# 1               11                    None    NaN        None            825B
# 2               10                    None    NaN        None            830A
# 3               11                    None    NaN        None            821B
# 4               11                    None    NaN        None            724B
#
#   sector  zone     rpa  latitude  longitude mapped_location
# 0     TE  623K  3107.0       NaN        NaN            None
# 1      N   617  4325.0       NaN        NaN            None
# 2     MT   833  7109.0       NaN        NaN            None
# 3      N   625  3173.0       NaN        NaN            None
# 4      N   627  3227.0       NaN        NaN            None

# %% [markdown]
# The Metro Police Department Incidents database

# %% [markdown]
# Add a table named "incidents" to your police_calls.sqlite database and load in the Metro_Nashville_Police_Department_Incidents.csv file

# %%
db = sqlite3.connect('data/hop_teaming.sqlite')

for chunk in tqdm(pd.read_csv('data/npidata_pfile_20050523-20210207.csv', chunksize = 10000)):
    chunk.columns = [x.lower().replace(' ', '_') for x in chunk.columns]      # Clean up the column names
    chunk.to_sql('providers', db, if_exists = 'append', index = False)            # Append the chunk to an incidents table
    
db.close()

# doing the same here as we did above with the 'team' table.  Calling this table 'providers'
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# C:\Users\daily\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3341: DtypeWarning: Columns (17,34,76,80,84,87,89,90,91,93,94,95,97,98,99,101,102,103,105,106,171,175,178,179,181,182,183,185,186,189,190,191,193,194,197,198,201,205,324,325,326,327,328) have mixed types.Specify dtype option on import or set low_memory=False.
#   await eval(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\daily\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3341: DtypeWarning: Columns (17,76,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,155,171,175,178,179,183,186,187,189,190,191,193,194,197,198,201,202,205,206,209,211,213,218,221,223,225,229,233,237,241,243,245,247,249,253,257,261,265,322,323,324,325,326,327,328) have mixed types.Specify dtype option on import or set low_memory=False.
#   await eval(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\daily\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3341: DtypeWarning: Columns (17,76,80,84,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,171,175,179,183,187,193,194,195,197,198,201,202,205,206,209,210,321,322,323,324,325,326,327,328) have mixed types.Specify dtype option on import or set low_memory=False.
#   await eval(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\daily\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3341: DtypeWarning: Columns (24,34,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,147,151,155,159,163,167,171,173,175,177,178,179,181,182,185,186,187,189,190,191,193,194,197,198,199,201,202,205,206,322,323,324,325,326,327,328) have mixed types.Specify dtype option on import or set low_memory=False.
#   await eval(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\daily\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3341: DtypeWarning: Columns (17,84,85,88,89,92,93,96,97,100,101,103,105,106,159,179,183,187,189,190,191,193,194,197,198,199,201,202,203,205,206,207,209,210,211,213,214,215,217,218,219,221,222,225,229,233,237,239,241,245,249,253,257,259,261,263,265,269,273,277,279,281,283,285,289,293,318,319,320,321,322,323,324,325,326,327,328) have mixed types.Specify dtype option on import or set low_memory=False.
#   await eval(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\daily\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3341: DtypeWarning: Columns (17,34,79,80,81,82,83,84,85,86,87,89,90,91,93,94,95,97,98,99,101,102,103,105,106,159,167,171,175,177,178,181,182,183,185,186,187,189,190,191,193,194,195,197,198,199,201,202,205,206,209,210,213,214,321,322,323,324,325,326) have mixed types.Specify dtype option on import or set low_memory=False.
#   await eval(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\daily\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3341: DtypeWarning: Columns (17,76,77,80,81,84,85,88,89,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,159,167,171,173,175,177,178,179,181,182,183,185,187,189,190,191,193,194,197,199,201,202,203,205,206,209,213,217,221,225,229,231,233,323,324,325,326,327,328) have mixed types.Specify dtype option on import or set low_memory=False.
#   await eval(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\daily\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3341: DtypeWarning: Columns (17,24,32,34,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,171,175,178,179,183,187,190,191,194,195,198,199,202,203,205,206,207,209,213,217,221,225,229,233,237,241,245,247,249,253,255,257,261,265,269,317,318,319,320,321,322,323,324,325,326,327,328) have mixed types.Specify dtype option on import or set low_memory=False.
#   await eval(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\daily\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3341: DtypeWarning: Columns (17,24,32,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,159,171,175,178,179,182,183,186,187,189,190,191,194,195,198,199,201,202,203,205,206,207,209,210,213,214,217,218,221,225,226,227,230,320,321,322,323,324,325,326,327,328) have mixed types.Specify dtype option on import or set low_memory=False.
#   await eval(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\daily\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3341: DtypeWarning: Columns (24,32,34,72,76,80,84,85,88,89,92,93,95,96,97,98,99,100,101,102,103,104,105,106,159,163,167,169,171,173,175,177,178,179,181,182,185,187,189,191,193,195,197,201,205,206,207,209,210,213,217,218,219,221,225,229,230,233,234,237,239,241,245,247,249,253,257,261,265,323,324,325,326,327,328) have mixed types.Specify dtype option on import or set low_memory=False.
#   await eval(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\daily\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3341: DtypeWarning: Columns (17,24,32,68,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,89,90,91,93,94,95,97,98,99,101,102,103,105,106,169,171,173,175,177,179,181,182,183,185,186,187,189,190,318,319,320,321,322,323,324,325,326) have mixed types.Specify dtype option on import or set low_memory=False.
#   await eval(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\daily\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3341: DtypeWarning: Columns (17,32,34,76,77,80,81,84,85,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,171,175,177,178,179,181,182,183,185,186,187,189,190,191,193,194,195,197,198,199,201,202,203,205,206,209,210,211,213,214,215,217,218,221,222,223,225,226,323,324,325,326,327,328) have mixed types.Specify dtype option on import or set low_memory=False.
#   await eval(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\daily\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3341: DtypeWarning: Columns (17,24,27,32,35,72,80,83,84,85,86,87,88,89,90,91,93,94,95,96,97,98,99,100,101,102,103,105,106,147,165,169,171,173,175,177,178,179,181,182,185,186,187,189,190,191,193,194,195,197,198,199,201,202,205,206,319,320,321,322,323,324,325,326,327,328) have mixed types.Specify dtype option on import or set low_memory=False.
#   await eval(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\daily\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3341: DtypeWarning: Columns (17,24,32,68,72,76,77,80,81,84,85,87,88,89,90,91,92,93,94,95,96,97,98,99,102,103,104,105,106,175,179,183,186,187,189,190,191,193,194,195,197,198,199,201,202,205,206,209,210,213,214,217,218,219,221,222,225,226,227,229,230,234,238,242,246,250,254,258,262,266,324,325,326,327,328) have mixed types.Specify dtype option on import or set low_memory=False.
#   await eval(code_obj, self.user_global_ns, self.user_ns)

# %%
# create a query on nppes which only calls in necessary columns 
db = sqlite3.connect('data/hop_teaming.sqlite')

query_nppes = '''
SELECT 
npi, entity_type_code AS entity_type, provider_organization_name_(legal_business_name) AS org_name, 
provider_last_name_(legal_name) AS prov_lastname, provider_first_name AS prov_firstname, provider_middle_name AS prov_midname, 
provider_name_suffix_text AS prov_suffix, provider_credential_text AS prov_credential, provider_other_last_name AS prov_otherlast, 
provider_first_line_business_practice_location_address AS prov_location1, provider_second_line_business_practice_location_address 
AS prov_location2, provider_business_practice_location_address_city_name AS prov_city, provider_business_practice_location_address_state_name
AS prov_state, provider_business_practice_location_address_postal_code AS prov_postal, 
healthcare_provider_taxonomy_code_1 AS tax_code1,
healthcare_provider_taxonomy_code_2 AS tax_code2,
healthcare_provider_taxonomy_code_3 AS tax_code3, 
healthcare_provider_taxonomy_code_4 AS tax_code4,
healthcare_provider_taxonomy_code_7 AS tax_code7,
healthcare_provider_primary_taxonomy_switch_1 AS tax_switch1,
healthcare_provider_primary_taxonomy_switch_2 AS tax_switch2,
healthcare_provider_primary_taxonomy_switch_3 AS tax_switch3, 
healthcare_provider_primary_taxonomy_switch_4 AS tax_switch4,
healthcare_provider_primary_taxonomy_switch_7 AS tax_switch7 

FROM providers

WHERE tax_switch1 = 'Y' OR tax_switch2 = 'Y' OR tax_switch3 = 'Y' OR tax_switch4 = 'Y' OR tax_switch7 = 'Y'

LIMIT 5; 
'''

nppes_sqlite = pd.read_sql(query_nppes, db)

db.close()

#taking the sqlite db and the specific 'nppes provider' table query and converting it to a python df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1585         try:
# -> 1586             cur.execute(*args, **kwargs)
#    1587             return cur
#
# OperationalError: no such table: providers
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-59-b06110e860a4> in <module>
#      28 '''
#      29
# ---> 30 nppes_sqlite = pd.read_sql(query_nppes, db)
#      31
#      32 db.close()
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     404
#     405     if isinstance(pandas_sql, SQLiteDatabase):
# --> 406         return pandas_sql.read_query(
#     407             sql,
#     408             index_col=index_col,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1631
#    1632         args = _convert_params(sql, params)
# -> 1633         cursor = self.execute(*args)
#    1634         columns = [col_desc[0] for col_desc in cursor.description]
#    1635
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1596
#    1597             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1598             raise ex from exc
#    1599
#    1600     @staticmethod
#
# DatabaseError: Execution failed on sql '
# SELECT
# npi, entity_type_code AS entity_type, provider_organization_name_(legal_business_name) AS org_name,
# provider_last_name_(legal_name) AS prov_lastname, provider_first_name AS prov_firstname, provider_middle_name AS prov_midname,
# provider_name_suffix_text AS prov_suffix, provider_credential_text AS prov_credential, provider_other_last_name AS prov_otherlast,
# provider_first_line_business_practice_location_address AS prov_location1, provider_second_line_business_practice_location_address
# AS prov_location2, provider_business_practice_location_address_city_name AS prov_city, provider_business_practice_location_address_state_name
# AS prov_state, provider_business_practice_location_address_postal_code AS prov_postal,
# healthcare_provider_taxonomy_code_1 AS tax_code1,
# healthcare_provider_taxonomy_code_2 AS tax_code2,
# healthcare_provider_taxonomy_code_3 AS tax_code3,
# healthcare_provider_taxonomy_code_4 AS tax_code4,
# healthcare_provider_taxonomy_code_7 AS tax_code7,
# healthcare_provider_primary_taxonomy_switch_1 AS tax_switch1,
# healthcare_provider_primary_taxonomy_switch_2 AS tax_switch2,
# healthcare_provider_primary_taxonomy_switch_3 AS tax_switch3,
# healthcare_provider_primary_taxonomy_switch_4 AS tax_switch4,
# healthcare_provider_primary_taxonomy_switch_7 AS tax_switch7
#
# FROM providers
#
# WHERE tax_switch1 = 'Y' OR tax_switch2 = 'Y' OR tax_switch3 = 'Y' OR tax_switch4 = 'Y' OR tax_switch7 = 'Y'
#
# LIMIT 5;
# ': no such table: providers

# %% [markdown]
# If we want to match calls to incidents, we can use the complaint_number column from the calls database and the incident_number column from the incidents database.
#
# To speed up this process, we can created indexes on these two columns.

# %%
# db = sqlite3.connect('data/hop_teaming.sqlite')

# db.execute('CREATE INDEX complaint_number ON calls(complaint_number)')
# db.execute('CREATE INDEX incident_number ON incidents(incident_number)')

# db.close()

#Q:  why create indexes again?  in order to join?  what happened to the other column that was indexed?
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-21-1e6661313f24> in <module>
#       1 db = sqlite3.connect('data/police_calls.sqlite')
#       2
# ----> 3 db.execute('CREATE INDEX complaint_number ON calls(complaint_number)')
#       4 db.execute('CREATE INDEX incident_number ON incidents(incident_number)')
#       5
#
# OperationalError: index complaint_number already exists

# %% [markdown]
# Now, let's grab all SHOTS FIRED calls for which there is an associated incident and bring in the incident information.

# %%
# query = """
# SELECT * FROM calls AS c 
# JOIN incidents AS i 
# ON c.complaint_number = i.incident_number 
# WHERE tencode_description = 'SHOTS FIRED'
# """

# %%
with sqlite3.connect('data/police_calls.sqlite') as db: 
    shots_sqlite = pd.read_sql(query, db)

#Q does this query name duplicate the earlier query name?  Yes, overrode the previous "query".  If orig query needs to be
#kept, then call this query diff name

# %%
shots_sqlite.shape
# Out:
# (1744, 50)

# %%
shots_sqlite.head()
# Out:
#      event_number           call_received  complaint_number shift  tencode  \
# 0  PD202000711384  09/23/2020 12:11:55 PM      2.020061e+10  None       83
# 1  PD202000711384  09/23/2020 12:11:55 PM      2.020061e+10  None       83
# 2  PD202000712332  09/23/2020 07:27:22 PM      2.020061e+10  None       83
# 3  PD202000712332  09/23/2020 07:27:22 PM      2.020061e+10  None       83
# 4  PD202000714837  09/24/2020 09:27:30 PM      2.020061e+10  None       83
#
#   tencode_description tencode_suffix tencode_suffix_description  \
# 0         SHOTS FIRED              R                     REPORT
# 1         SHOTS FIRED              R                     REPORT
# 2         SHOTS FIRED              P                   PROGRESS
# 3         SHOTS FIRED              P                   PROGRESS
# 4         SHOTS FIRED              R                     REPORT
#
#   disposition_code disposition_description  ...  weapon_description  \
# 0                1                    None  ...                CLUB
# 1                1                    None  ...                CLUB
# 2               10                    None  ...                NONE
# 3               10                    None  ...                NONE
# 4                1                    None  ...                NONE
#
#   victim_number domestic_related victim_type        victim_description  \
# 0             1                0           I  INDIVIDUAL (18 AND OVER)
# 1             1                0           I  INDIVIDUAL (18 AND OVER)
# 2             1                0           U                   UNKNOWN
# 3             1                0           U                   UNKNOWN
# 4             1                0           I  INDIVIDUAL (18 AND OVER)
#
#    victim_gender  victim_race  victim_ethnicity victim_county_resident  \
# 0              M            B      Non-Hispanic               RESIDENT
# 1              M            B      Non-Hispanic               RESIDENT
# 2              U            U      Non-Hispanic                   None
# 3              U            U      Non-Hispanic                   None
# 4              M            W          Hispanic               RESIDENT
#
#           mapped_location
# 0    POINT (-86.67 36.04)
# 1    POINT (-86.67 36.04)
# 2                    None
# 3                    None
# 4  POINT (-86.653 36.054)
#
# [5 rows x 50 columns]
